# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # CVAE example on MNIST
#
# From https://github.com/elttaes/VAE-MNIST-Haiku-Jax/blob/main/cVAE_mnist.ipynb

# %%
from torchvision import datasets, transforms
import numpy as np
from torch.utils.data import DataLoader
import haiku as hk
import jax
import jax.numpy as jnp
import numpy as np
from typing import List
import optax
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle

data_path = './'

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transforms.Compose([
    transforms.ToTensor()
]))

mnist_val = datasets.MNIST(data_path, train=False, download=True, transform=transforms.Compose([
    transforms.ToTensor()
]))

train_loader = DataLoader(mnist_train, batch_size=64,
                          shuffle=True, pin_memory=True, drop_last=True)

val_loader = DataLoader(mnist_val, batch_size=1,
                        shuffle=False, pin_memory=True, drop_last=True)


class VAE_Encoder(hk.Module):
    def __init__(self, hidden_dims: List = None, name='VAE_Encoder'):
        super().__init__(name=name)
        if hidden_dims is None:
            hidden_dims = [64, 64]
        self.modules = []
        for h_dim in hidden_dims:
            self.modules.append((hk.Conv2D(output_channels=h_dim,
                                           kernel_shape=3, stride=2, padding=[1, 1]), hk.BatchNorm(create_scale=True, create_offset=True, decay_rate=0.999)))
        self.fc_mu = hk.Linear(2)
        self.fc_var = hk.Linear(2)

    def __call__(self, x):
        for layer_i, bn_i in self.modules:
            x = layer_i(x)
            x = bn_i(x, is_training=True)
            x = jax.nn.leaky_relu(x)
        x = hk.Flatten()(x)
        mean = self.fc_mu(x)
        log_std = self.fc_var(x)
        return [mean, log_std]


class VAE_Decoder(hk.Module):
    def __init__(self, hidden_dims: List = None, name='VAE_Decoder'):
        super().__init__(name=name)
        if hidden_dims is None:
            self.hidden_dims = [64, 64]
        self.modules = []
        self.conv_dim = 7
        for h_dim in self.hidden_dims:
            self.modules.append((hk.Conv2DTranspose(output_channels=h_dim,
                                                    kernel_shape=3, stride=2), hk.BatchNorm(create_scale=True, create_offset=True, decay_rate=0.999)))
        self.finally_Linear = hk.Linear(1)
        self.decoder_input = hk.Linear(self.conv_dim*self.conv_dim*self.hidden_dims[-1])

    def __call__(self, x):
        x = self.decoder_input(x)
        x = x.reshape(-1, self.conv_dim, self.conv_dim, self.hidden_dims[-1])
        for layer_i, bn_i in self.modules:
            x = layer_i(x)
            x = bn_i(x, is_training=True)
            x = jax.nn.leaky_relu(x)
        x = self.finally_Linear(x)
        x = jax.nn.sigmoid(x)
        return x
    
    
class CVAE(hk.Module):
    def __init__(self, encoder, decoder, name='CVAE'):
        super().__init__(name=name)
        self.encoder = encoder
        self.decoder = decoder
    def __call__(self, batch):
        x, y = batch[0], batch[1]
        mu, log_var = self.encoder(x)
        z = reparameterize(mu, log_var)
        y = jax.nn.one_hot(y,10)
        z = jnp.concatenate([z, y], axis=1)
        z = self.decoder(z)
        return z, x, mu, log_var

def reparameterize(mean, stddev):
    z = mean + stddev * jax.random.normal(hk.next_rng_key(), mean.shape)
    return z

def vae():
    encoder = VAE_Encoder()
    decoder = VAE_Decoder()
    cvae = CVAE(encoder, decoder)
    def init(batch):
        x, y = batch[0], batch[1]
        mu, log_var = encoder(x)
        z = reparameterize(mu, log_var)
        y = jax.nn.one_hot(y,10)
        z = jnp.concatenate([z, y], axis=1)
        z = decoder(z)
        return [z, x, mu, log_var]
    return init, (cvae, encoder, decoder)

def vae_loss(params: hk.Params, state, batch, model):
    loss_input, state = model(params, state, rng_key, batch)
    recons = loss_input[0]
    ori_image = loss_input[1]
    mean = loss_input[2]
    var = loss_input[3]
    recons_loss = optax.l2_loss(recons, ori_image[:,:,:,:1])
    kld_loss = jnp.mean(-0.5 * jnp.sum(1 + var - mean**2 -
                        jnp.exp(var), axis=1), axis=0)
    loss = recons_loss + kld_loss* 0.00025
    return loss.mean()

vae_t = hk.multi_transform_with_state(vae)
rng_key = jax.random.PRNGKey(42)
dummy_x = jax.random.normal(rng_key, (8, 28, 28, 2))
dummy_y = jax.random.normal(rng_key, (8,))
params, state = vae_t.init(rng=rng_key, batch=[dummy_x,dummy_y])
cvae, encoder, decoder = vae_t.apply

# %%
import seaborn as sns
res,state = cvae(params, state,rng_key, [dummy_x,dummy_y])
sns.histplot(res[0][0].flatten(), bins=50, element='step') 
plt.show()

# %%
@jax.jit
def step(params, opt_state, state, batch):
    loss_value, grads = jax.value_and_grad(vae_loss)(params, state, batch, cvae)
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss_value

def train(train_loader, val_loader, params, state, opt_state):
    for epoch in range(2):
        for x, y in tqdm(train_loader):
            x = jnp.array(x)
            y = jnp.array(y)
            y_1 = jnp.tile(y[:,None,None,None], (1, 1, 28, 28))
            x = jnp.concatenate((x,y_1), axis=1)
            x = jnp.transpose(x, (0, 2, 3, 1))
            params, opt_state, loss_value = step(params, opt_state, state,[x ,y])
        [x, y] = next(iter(val_loader))
        x = jnp.array(x)
        y = jnp.array([7])
        y_1 = jnp.tile(y[:,None,None,None], (1, 1, 28, 28))
        x = jnp.concatenate((x,y_1), axis=1)
        x = jnp.transpose(x, (0, 2, 3, 1))
        res,state = cvae(params, state,rng_key, [x,y])
        plt.imshow(res[0][0].reshape(28,28))
        plt.show()
    return params, state, opt_state, x, y, res

optimizer = optax.adamw(learning_rate=0.001)
opt_state = optimizer.init(params)

params, state, opt_state, x, y, res = train(train_loader, val_loader, params, state, opt_state)
# Out:
# ...
# 100%|██████████| 937/937 [00:03<00:00, 258.89it/s]

# %%
n_samples = 6*6
c_fake = jax.random.randint(rng_key, (n_samples,), 0, 10)
c_fake = jax.nn.one_hot(c_fake, 10)
z_fake = jax.random.normal(rng_key, (n_samples, 2))
z_fake = jnp.concatenate([z_fake, c_fake], axis=1)
fake_imgs, _ = jax.vmap(decoder, in_axes=(None, None, None, 0))(params, state, rng_key, z_fake)

# %%
rows = int(np.ceil(np.sqrt(n_samples)))
cols = int(np.ceil(np.sqrt(n_samples)))
plt.figure(figsize=(3*cols, 3*rows))
for i in range(n_samples):
    plt.subplot(rows, cols, i+1)
    plt.imshow(fake_imgs[i].reshape(28,28))
    plt.title(np.where(c_fake[i])[0][0])

# %% [markdown]
# # Experimenting

# %%
from torchvision import datasets, transforms
import numpy as np
from torch.utils.data import DataLoader
import haiku as hk
import jax
import jax.numpy as jnp
import numpy as np
from typing import List
import optax
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import pickle


data_path = './'

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transforms.Compose([
    transforms.ToTensor()
]))

mnist_val = datasets.MNIST(data_path, train=False, download=True, transform=transforms.Compose([
    transforms.ToTensor()
]))

train_loader = DataLoader(mnist_train, batch_size=64,
                          shuffle=True, pin_memory=True, drop_last=True)

val_loader = DataLoader(mnist_val, batch_size=1,
                        shuffle=False, pin_memory=True, drop_last=True)


class VAE_Encoder(hk.Module):
    def __init__(self, hidden_dims: List = None, name='VAE_Encoder'):
        super().__init__(name=name)
        if hidden_dims is None:
            hidden_dims = [64, 64]
        self.modules = []
        for h_dim in hidden_dims:
            # self.modules.append((hk.Conv2D(output_channels=h_dim,
            #                                kernel_shape=3, stride=2, padding=[1, 1]), hk.BatchNorm(create_scale=True, create_offset=True, decay_rate=0.999)))
            self.modules.append(
                (hk.Linear(h_dim), hk.BatchNorm(create_scale=True, create_offset=True, decay_rate=0.999)))
            
        self.fc_mu = hk.Linear(2)
        self.fc_var = hk.Linear(2)

    def __call__(self, x):
        x = hk.Flatten()(x)
        for layer_i, bn_i in self.modules:
            x = layer_i(x)
            x = bn_i(x, is_training=True)
            x = jax.nn.leaky_relu(x)
        x = hk.Flatten()(x)
        return x
        # mean = self.fc_mu(x)
        # log_std = self.fc_var(x)
        # return [mean, log_std]


class VAE_Decoder(hk.Module):
    def __init__(self, hidden_dims: List = None, name='VAE_Decoder'):
        super().__init__(name=name)
        if hidden_dims is None:
            self.hidden_dims = [64, 64]
        self.modules = []
        self.conv_dim = 7
        for h_dim in self.hidden_dims:
            # self.modules.append((hk.Conv2DTranspose(output_channels=h_dim, #w_init=hk.initializers.VarianceScaling(scale=2.0),
            #                                         kernel_shape=3, stride=2), hk.BatchNorm(create_scale=True, create_offset=True, decay_rate=0.999)))
            self.modules.append(
                (hk.Linear(h_dim), hk.BatchNorm(create_scale=True, create_offset=True, decay_rate=0.999)))
            
        self.finally_Linear = hk.Linear(28*28)
        self.decoder_input = hk.Linear(self.conv_dim*self.conv_dim*self.hidden_dims[-1])

    def __call__(self, x):
        x = self.decoder_input(x)
        # x = x.reshape(-1, self.conv_dim, self.conv_dim, self.hidden_dims[-1])
        for layer_i, bn_i in self.modules:
            x = layer_i(x)
            x = bn_i(x, is_training=True)
            x = jax.nn.leaky_relu(x)
        x = self.finally_Linear(x)
        x = jax.nn.sigmoid(x)
        # x = jax.nn.leaky_relu(x)
        return x
    
    
class CVAE(hk.Module):
    def __init__(self, encoder, decoder, name='CVAE'):
        super().__init__(name=name)
        self.encoder = encoder
        self.decoder = decoder
        self.fc_mu = hk.Linear(2)
        self.fc_var = hk.Linear(2)
    def __call__(self, batch, rng_key):
        x, y = batch[0], batch[1]
        # mu, log_var = self.encoder(x)
        h = self.encoder(x)
        mu = self.fc_mu(h)
        log_var = self.fc_var(h)
        z = reparameterize(mu, log_var, rng_key)
        y = jax.nn.one_hot(y,10)
        zc = jnp.concatenate([z, y], axis=1)
        rec = self.decoder(zc)
        # rec = rec.reshape(-1, jnp.sqrt(x.shape[-1]), jnp.sqrt(x.shape[-1]), 1)
        rec = rec.reshape(-1, 28, 28, 1)
        return [rec, zc, z, h, x, mu, log_var]

def reparameterize(mean, stddev, rng_key):
    z = mean + stddev * jax.random.normal(rng_key, mean.shape)
    return z

def vae():
    encoder = VAE_Encoder()
    decoder = VAE_Decoder()
    cvae = CVAE(encoder, decoder)
    def init(batch, rng_key):
        x, y = batch[0], batch[1]
        # mu, log_var = encoder(x)
        h = encoder(x)
        mu = cvae.fc_mu(h)
        log_var = cvae.fc_var(h)
        z = reparameterize(mu, log_var, rng_key)
        y = jax.nn.one_hot(y,10)
        zc = jnp.concatenate([z, y], axis=1)
        rec = decoder(zc)
        return [rec, zc, z, h, x, mu, log_var]
    return init, (cvae, encoder, decoder)

def vae_loss(params: hk.Params, state, batch, model):
    loss_input, state = model(params, state, rng_key, batch, rng_key=rng_key)
    recons = loss_input[0]
    zc = loss_input[1]
    z = loss_input[2]
    h = loss_input[3]
    ori_image = loss_input[4]
    mean = loss_input[5]
    var = loss_input[6]
    recons_loss = optax.l2_loss(recons, ori_image[:,:,:,:1])
    kld_loss = jnp.mean(-0.5 * jnp.sum(1 + var - mean**2 -
                        jnp.exp(var), axis=1), axis=0)
    loss = recons_loss + kld_loss* 0.00025
    return loss.mean()

vae_t = hk.multi_transform_with_state(vae)
rng_key = jax.random.PRNGKey(42)
n_to_sample = 1000
dummy_x = jax.random.normal(rng_key, (n_to_sample, 28, 28, 2))
dummy_y = jax.random.normal(rng_key, (n_to_sample,))
params, state = vae_t.init(rng=rng_key, batch=[dummy_x,dummy_y], rng_key=rng_key)
cvae, encoder, decoder = vae_t.apply

# %%
res,state = cvae(params, state,rng_key, [dummy_x,dummy_y], rng_key=rng_key)
rec, zc, z, h, x, mu, log_var = res
kk = ['rec', 'z', 'h', 'mu', 'log_var']
fig = plt.figure(figsize=(5*len(kk), 4))
for k, l in zip(kk, [rec, z, h, mu, log_var]):
    ax = fig.add_subplot(1, len(kk), kk.index(k)+1)
    sns.histplot(l.flatten() if (l.shape[-1] > 4) or (l.ndim > 2) else l, bins=50, element='step')
    plt.title(k)

# %%
@jax.jit
def step(params, opt_state, state, batch):
    loss_value, grads = jax.value_and_grad(vae_loss)(params, state, batch, cvae)
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss_value

def train(train_loader, val_loader, params, state, opt_state):
    for epoch in range(2):
        for x, y in tqdm(train_loader):
            x = jnp.array(x)
            y = jnp.array(y)
            y_1 = jnp.tile(y[:,None,None,None], (1, 1, 28, 28))
            x = jnp.concatenate((x,y_1), axis=1)
            x = jnp.transpose(x, (0, 2, 3, 1))
            params, opt_state, loss_value = step(params, opt_state, state,[x ,y])
        [x, y] = next(iter(val_loader))
        x = jnp.array(x)
        y = jnp.array([7])
        y_1 = jnp.tile(y[:,None,None,None], (1, 1, 28, 28))
        x = jnp.concatenate((x,y_1), axis=1)
        x = jnp.transpose(x, (0, 2, 3, 1))
        res,state = cvae(params, state,rng_key, [x,y], rng_key=rng_key)
        # plt.imshow(res[0][0].reshape(28,28))
        # plt.show()
    return params, state, opt_state, x, y, res

optimizer = optax.adamw(learning_rate=0.001)
opt_state = optimizer.init(params)

params, state, opt_state, x, y, res = train(train_loader, val_loader, params, state, opt_state)
# Out:
# ...
# 100%|██████████| 937/937 [00:06<00:00, 151.49it/s]

# %% [markdown]
# ## Vis

# %%
res,state = cvae(params, state,rng_key, [dummy_x,dummy_y], rng_key=rng_key)
rec, zc, z, h, x, mu, log_var = res
kk = ['rec', 'z', 'h', 'mu', 'log_var']
fig = plt.figure(figsize=(5*len(kk), 4))
for k, l in zip(kk, [rec, z, h, mu, log_var]):
    ax = fig.add_subplot(1, len(kk), kk.index(k)+1)
    sns.histplot(l.flatten() if (l.shape[-1] > 4) or (l.ndim > 2) else l, bins=50, element='step')
    plt.title(k)

# %%
rows = int(np.ceil(np.sqrt(n_samples)))
cols = int(np.ceil(np.sqrt(n_samples)))
plt.figure(figsize=(3*cols, 3*rows))
for i in range(n_samples):
    plt.subplot(rows, cols, i+1)
    plt.imshow(fake_imgs[i].reshape(28,28))
    plt.title(np.where(c_fake[i])[0][0])

# %%
# Potential diagnostic code
def print_layer_stats(model):
    for name, module in model.items():
        if 'w' in module:
            print(f"Layer {name}:")
            print(f"  Weight mean: {module['w'].mean().item()}")
            print(f"  Weight std: {module['w'].std().item()}")

print_layer_stats(params)
# Out:
# Layer CVAE/~/linear:
#   Weight mean: 0.0023052976466715336
#   Weight std: 0.11427976936101913
# Layer CVAE/~/linear_1:
#   Weight mean: -0.00048811454325914383
#   Weight std: 0.09499163925647736
# Layer VAE_Decoder/~/linear:
#   Weight mean: 4.5852677430957556e-05
#   Weight std: 0.03256387263536453
# Layer VAE_Decoder/~/linear_1:
#   Weight mean: -0.011940408498048782
#   Weight std: 0.1199142187833786
# Layer VAE_Decoder/~/linear_2:
#   Weight mean: -0.08149021118879318
#   Weight std: 0.13525813817977905
# Layer VAE_Decoder/~/linear_3:
#   Weight mean: 0.000365851738024503
#   Weight std: 0.25419098138809204
# Layer VAE_Encoder/~/linear:
#   Weight mean: 0.0010051088174805045
#   Weight std: 0.046772394329309464
# Layer VAE_Encoder/~/linear_1:
#   Weight mean: -0.0086981151252985
#   Weight std: 0.11880069971084595
