# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
# Out:
# '/home/hslab/Olive/Kode/EvoScaper/visualisations'

# %%
os.listdir('../../synbio_morpher/data/ensemble_mutation_effect_analysis')
# Out:
# ['2024_11_09_164634',
#  '2024_11_27_145142',
#  '2024_11_11_135219',
#  '2024_11_20_153740',
#  '2024_11_21_160955',
#  '2024_11_20_224946']

# %%
len()
